# %% [markdown]
# # Backend Profiling — Pre-optimization Baseline [code913.0]
#
# Profiles the `lfilter` cascade backend **before** any optimization was applied.
# The "before" implementations are patched in at the start of the session so every call in this
# notebook uses C-order scratch buffers and C-order `xi_curr`, exactly replicating pre-optimization behaviour.
#
# > **Scope**: fixed model — `AlssmPoly(poly_degree=1)`, forward segment `g=100` → **N = 2** states.
#
# **API at a glance:**
# ```python
# lm.profiling.enable()        # start collecting
# lm.profiling.disable()       # stop collecting (zero overhead)
# lm.profiling.clear()         # discard all records
# lm.profiling.report()        # print summary + cProfile table
# lm.profiling.get_records()   # raw {func_name: [_Record, ...]}
# ```
#
# **Series:**
# - **[code913.0](coding-code913.0-profile.ipynb)** ← this notebook — pre-optimization profile, hotspot identification
# - **[code913.1](coding-code913.1-cascade-variants.ipynb)** — C-order vs F-order `xi0` scratch buffer, benchmarked in isolation
# - **[code913.2](coding-code913.2-profile-higher-order.ipynb)** — same two variants swept over ALSSM order N = 2 … 8
# - **[code913.3](coding-code913.3-applied.ipynb)** — explicit before/after pipeline benchmark (C-order vs F-order `xi_curr`)

# %%
import numpy as np
import matplotlib.pyplot as plt
import lmlib as lm

lm.WARNING_NOT_STEADY_STATE = False

# %%
import lmlib.statespace.backends.rec_lfilter as _rlf_mod
from lmlib.utils.profiling import profile as _profile
from gu133_before_impl import (
    lfilter_forward_cascade_xi,
    lfilter_backward_cascade_xi,
    nd_xi_q_recursion,
)

# Save originals so the cleanup cell (last cell) can restore them, even if a
# cell fails mid-run.
_orig_fw  = _rlf_mod.lfilter_forward_cascade_xi
_orig_bw  = _rlf_mod.lfilter_backward_cascade_xi
_orig_nd  = lm.RLSAlssm._nd_xi_q_recursion

_rlf_mod.lfilter_forward_cascade_xi  = _profile(lfilter_forward_cascade_xi)
_rlf_mod.lfilter_backward_cascade_xi = _profile(lfilter_backward_cascade_xi)
lm.RLSAlssm._nd_xi_q_recursion       = nd_xi_q_recursion

print("✓ Before-implementations patched in.")
# Out:
# ✓ Before-implementations patched in.

# %% [markdown]
# ## Signal & model setup
#
# Same model as code910.0: polynomial ALSSM order 1, forward segment with exponential decay.
# We vary signal length `K` to see how time and memory scale.

# %%
alssm = lm.AlssmPoly(poly_degree=1)
seg_l = lm.Segment(a=-21, b=-1, direction=lm.FW, g=100)
cost  = lm.CompositeCost([alssm], [seg_l], F=[[1]])

rls = lm.RLSAlssm(cost, backend='lfilter', steady_state=False,
                   calc_W=False, calc_kappa=False, calc_nu=False)

Ks = [1_000, 10_000, 100_000, 1_000_000]

# %% [markdown]
# ## Collect profiling data
#
# Each signal length `K` is run **`N_repeat` times** on the same signal.
# This gives a distribution of wall times per function, from which we report median, min, and max. We report median since mean could skew the results.
# `lm.profiling.clear()` is called once per K so records from different lengths don't mix.

# %%
N_repeat = 50  # number of repeated filter() calls per K

lm.profiling.enable()

# warm-up — prime caches and any lazy init before measuring
rls.filter(np.random.randn(1_000))
lm.profiling.clear()

records_per_K = {}
for K in Ks:
    y = np.random.randn(K)
    lm.profiling.clear()
    for _ in range(N_repeat):
        rls.filter(y)   # each call appends one _Record per profiled function
    records_per_K[K] = {
        name: list(recs)
        for name, recs in lm.profiling.get_records().items()
    }

lm.profiling.disable()

func_names = list(next(iter(records_per_K.values())).keys())
print(f"N_repeat={N_repeat}, Ks={Ks}")
print(f"Functions profiled: {func_names}")

# Show per-K summary; flag records that had high CPU at call time
import math
CPU_THRESH = lm.profiling.CPU_WARN_THRESHOLD
print(f"\n{'K':>10}  {'function':<40}  {'median ms':>10}  {'min ms':>8}  {'max ms':>8}  {'cpu %':>7}  {'reliable':>8}")
print("─" * 102)
for K in Ks:
    for name, recs in records_per_K[K].items():
        t       = np.array([r.elapsed_s * 1e3 for r in recs])
        cpu     = np.array([r.cpu_percent for r in recs])
        n_noisy = sum(1 for r in recs if not r.is_reliable)
        cpu_med = float(np.nanmedian(cpu))
        cpu_str = f"{cpu_med:5.1f}%" if not math.isnan(cpu_med) else "  n/a "
        flag    = f" {n_noisy}/{len(recs)} ⚠" if n_noisy else f" {len(recs)}/{len(recs)}"
        print(f"{K:>10,}  {name:<40}  {np.median(t):>10.2f}  {t.min():>8.2f}  {t.max():>8.2f}  {cpu_str:>7}  {flag:>8}")
# Out:
# N_repeat=50, Ks=[1000, 10000, 100000, 1000000]
# Functions profiled: ['lfilter_forward_cascade_xi']
#
#          K  function                                   median ms    min ms    max ms    cpu %  reliable
# ──────────────────────────────────────────────────────────────────────────────────────────────────────
#      1,000  lfilter_forward_cascade_xi                      0.94      0.91      1.14     0.0%     50/50
#     10,000  lfilter_forward_cascade_xi                      1.32      1.27      1.57     0.0%     50/50
#    100,000  lfilter_forward_cascade_xi                      6.91      6.67      8.13     7.7%     50/50
#  1,000,000  lfilter_forward_cascade_xi                     51.81     50.52     59.52     6.9%     50/50

# %% [markdown]
# ## cProfile report
#
# Full sub-call breakdown for the largest `K`.
# Sorted by cumulative time, top 20 entries.

# %%
lm.profiling.enable()
lm.profiling.clear()
rls.filter(np.random.randn(Ks[-1]))
lm.profiling.disable()

lm.profiling.report(top=20)
# Out:
# ────────────────────────────────────────────────────────────────────
#   lfilter_forward_cascade_xi
#   calls=1/1  avg=55.24 ms  max=55.24 ms  avg_peak=62525.5 KB  max_peak=62525.5 KB
# ────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## Line-by-line timing inside `lfilter_forward_cascade_xi`
#
# Uses `line_profiler.LineProfiler` to measure the time spent on **each line** of the function.
# Run at `K = 1_000_000` so timing differences are clearly visible.

# %%
import io
import inspect
from line_profiler import LineProfiler

# Use the file-backed before-implementation so inspect.getsource() works.
# lfilter_forward_cascade_xi is the undecorated function from _before_mod.
lfilter_forward_unwrapped = lfilter_forward_cascade_xi   # already the raw function, no unwrap needed

K_lp = 1_000_000
y_lp = np.random.randn(K_lp)

rls_lp = lm.RLSAlssm(cost, backend='lfilter', steady_state=False,
                      calc_W=False, calc_kappa=False, calc_nu=False)
rls_lp.filter(np.random.randn(1_000))  # warm-up

lp = LineProfiler()
lp.add_function(lfilter_forward_unwrapped)
lp_filter = lp(rls_lp.filter)

# Run N_repeat times — LineProfiler accumulates total hits and total time.
# output_unit is divided by N_repeat so "Time" and "Total time" reflect a
# single average call rather than the 20-run sum.
for _ in range(N_repeat):
    lp_filter(y_lp)

buf = io.StringIO()
lp.print_stats(stream=buf, output_unit=1e-3 / N_repeat, stripzeros=True)  # times in ms, per-call average
print(f"Lines timed over {N_repeat} repeated calls  (Time = per-call average ms)\n")
print(buf.getvalue())
# Out:
# Lines timed over 50 repeated calls  (Time = per-call average ms)
#
# Timer unit: 2e-05 s
#
# Total time: 2.54614 s
# File: /esat/biomeddata/pdevogel/projects/lmlib/coding/13-backend/gu133_before_impl.py
# Function: lfilter_forward_cascade_xi at line 36
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     36                                           def lfilter_forward_cascade_xi(xi, A, C, a, b, delta, gamma, y, v, beta):
#     37                                               """Before: C-order xi0 scratch buffer; xi += xi0 accumulation copy."""
#     38        50          2.7      0.1      0.0      if not (a < 0 and b <= 0):
#     39                                                   raise NotImplementedError('BACKEND: a and b has to be lower then zero for forward calculated segments.')
#     40        50          2.2      0.0      0.0      gamma_inv = 1 / gamma
#     41        50          5.4      0.1      0.0      gamma_a   = gamma ** (a - 1 - delta)
#     42        50          1.5      0.0      0.0      gamma_b   = gamma ** (b - delta)
#     43        50        143.2      2.9      0.1      gAinvT    = gamma_inv * _inv(A).T
#     44        50        180.2      3.6      0.1      Aac       = np.dot(_mpow(A, 0 if np.isinf(a) else a - 1).T, C.T)
#     45        50         70.2      1.4      0.1      Abc       = np.dot(_mpow(A, b).T, C.T)
#     46        50          5.1      0.1      0.0      N         = np.shape(A)[1]
#     47        50        321.7      6.4      0.3      if not np.allclose(gAinvT, np.tril(gAinvT)):
#     48                                                   raise ValueError('State-Space Matrix A needs to be upper triangular for cascaded version')
#     49        50       3907.6     78.2      3.1      vy = y * v[:, None]
#     50        50         33.8      0.7      0.0      y_delayed_b = np.empty_like(vy)
#     51        50         11.3      0.2      0.0      y_delayed_b[:-b] = 0
#     52        50       3819.5     76.4      3.0      y_delayed_b[-b:] = vy[:b]
#     53        50      19857.7    397.2     15.6      y_diff = np.einsum('kl,nl->kn', y_delayed_b, gamma_b * Abc)
#     54        50         29.4      0.6      0.0      if not np.isinf(a):
#     55        50         50.1      1.0      0.0          y_delayed_a = np.empty_like(vy)
#     56        50         15.1      0.3      0.0          y_delayed_a[:-a + 1] = 0
#     57        50       5612.8    112.3      4.4          y_delayed_a[-a + 1:] = vy[:a - 1]
#     58        50      23663.5    473.3     18.6          y_diff -= np.einsum('kl,nl->kn', y_delayed_a, gamma_a * Aac)
#     59                                               # iterating through dimensions
#     60        50         37.2      0.7      0.0      y_diff = np.swapaxes(y_diff, 0, 1)  # convenient for later indexing
#     61        50       2121.9     42.4      1.7      xi0 = np.zeros_like(xi)
#     62        50          0.8      0.0      0.0      n_ = 0
#     63        50      22907.4    458.1     18.0      xi0[:, n_] = _lfilter([1, 0], [1, -gamma_inv], y_diff[n_].T).T
#     64       100         10.8      0.1      0.0      for n_ in range(1, N):
#     65        50      19786.6    395.7     15.5          y_diff[n_, 1:] += np.einsum('kn..., n->k...', xi0[:-1], gAinvT[n_])
#     66        50      20329.8    406.6     16.0          xi0[:, n_] = _lfilter([1, 0], [1, -gamma_inv], y_diff[n_].T).T
#     67        50       4373.9     87.5      3.4      xi += xi0                         # <- accumulation copy (before)
#     68        50          5.4      0.1      0.0      if beta != 1:
#     69                                                   xi *= beta
#
# Total time: 2.67081 s
# File: /esat/biomeddata/pdevogel/projects/lmlib/lmlib/statespace/rls.py
# Function: RLSAlssm.filter at line 346
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    346                                               def filter(self, y, sample_weights=None, dim_order=None):
#    347                                                   r"""
#    348                                                   Calculates the ALSSM cost parameters :math:`\xi^{(q)}(k,y)` for :math:`q \in \{0,1,2\}` and :math:`\nu_k` based on an input signal :math:`y`.
#    349
#    350                                                   The cost parameters :math:`\xi^{(q)}(k,y)` for :math:`q \in \{0,1,2\}` are equivalent to :math:`\kappa_k`, :math:`\xi_k` and :math:`W_k`. They are calculated through the recursive equations (22-25) [Wildhaber2018]_ for each cost segment defined by the different backends.
#    351                                                   This function validates if every parameter has the right dimensions and redirects to each :math:`q`. It also coordinates the recursion steps across dimensions: :meth:`_nd_xi_q_recursion()` for the first dimension, :meth:`_nd_xi_q_asterisk_l_recursion()` for the subsequent ones.
#    352                                                   TODO: calculate :math:`\nu_k`.
#    353
#    354                                                   Parameters
#    355                                                   ----------
#    356                                                   y : array_like of shape (K, [Q])
#    357                                                       Input signal. The Q dimension is the ALSSM output dimension, and for scalar ALSSMs (Q=0) a 1D array is also accepted.
#    358                                                   sample_weights : array_like of shape (K,), optional
#    359                                                       Per-sample weights :math:`w_i \in \[0,1\]`. Default: all ones.
#    360                                                   dim_order : array_like of int, optional
#    361                                                       Has no effect for :class:`CostSegment` and :class:`CompositeCost`. The order in which ND dimensions are reduced in the recursion for :class:`NDCompositeCost`. Default: np.arange(L) with L number of dimensions.
#    362
#    363                                                   Notes
#    364                                                   -----
#    365                                                   When `steady_state=True`, :math:`W_k` is precomputed once as a constant :math:`W` regardless of `calc_W`. This is valid when all window parameters are independent of :math:k (i.e., :math:`w_k = w` and :math:\gamma_k = \gamma), in which case the :math:`W_k` recursion converges to a steady state satisfying a Lyapunov equation (see Section III-I.2 in [Wildhaber2018]_).
#    366                                                   The code uses :math:`Q=0` to mean a :math:`1\times1` scalar, not zero-dimensional.
#    367
#    368                                                   Returns
#    369                                                   -------
#    370                                                   None
#    371                                                       Results are stored in-place and accessed via :attr:`W`, :attr:`xi`, and :attr:`kappa`.
#    372
#    373                                                   Raises
#    374                                                   ------
#    375                                                   ValueError
#    376                                                       If `y` has wrong shape.
#    377                                                       If `sample_weights` has wrong shape.
#    378                                                   AssertionError
#    379                                                       If `dim_order` has wrong length.
#    380                                                   """
#    381
#    382                                                   # -------- check dimension order --------
#    383        50          6.6      0.1      0.0          L = self._cost_terms.get_number_of_dimensions()
#    384        50          0.7      0.0      0.0          if dim_order is None:
#    385        50         20.0      0.4      0.0              dim_order = np.arange(L)
#    386        50          3.8      0.1      0.0          assert len(dim_order) == L, f'dim_order has wrong length, {info_str_found_shape(dim_order)}'
#    387        50          1.0      0.0      0.0          if L > 1 and self._calc_W and not self._steady_state:
#    388                                                       assert False, "for multidimensional ALSSMs, W requires steady_state=True"
#    389
#    390                                                   # -------- broadcast and check y --------
#    391        50       1132.3     22.6      0.8          Q = self._cost_terms.get_alssm_output_dimension()
#    392        50          1.4      0.0      0.0          y = np.asarray(y)
#    393        50          2.6      0.1      0.0          if isinstance(self._cost_terms, (CompositeCost, CostSegment)):
#    394        50          0.8      0.0      0.0              if Q == 0:  # scalar output
#    395        50          0.8      0.0      0.0                  if y.ndim == 1:  # 1 dim signal
#    396        50          6.1      0.1      0.0                      y = y.reshape(-1, 1)
#    397                                                           elif y.ndim >= 2:
#    398                                                               if y.shape[1] == 1:
#    399                                                                   pass #already has correct dimension
#    400                                                               elif y.shape[-1] != 1:  # multi dimension signal (processed in parallel)
#    401                                                                   y = y.reshape(*y.shape, 1)
#    402                                                               else:
#    403                                                                   raise ValueError(f'y has wrong dimension, {info_str_found_shape(y)}')
#    404                                                           else:
#    405                                                               raise ValueError(f'y has wrong dimension, {info_str_found_shape(y)}')
#    406                                                       elif Q == 1:  # 1-dimensional output
#    407                                                           if y.ndim == 1 or y.shape[-1] != Q:
#    408                                                               raise ValueError(f'y has wrong dimension, {info_str_found_shape(y)}')
#    409                                                       else:
#    410                                                           if y.shape[-1] != Q:
#    411                                                               raise ValueError(f'y has wrong dimension, {info_str_found_shape(y)}')
#    412
#    413        50          4.6      0.1      0.0          if isinstance(self._cost_terms, NDCompositeCost):
#    414                                                       if Q == 0:  # scalar output
#    415                                                           if y.ndim == L:
#    416                                                               y = y.reshape(*y.shape, 1)
#    417                                                           else:
#    418                                                               raise ValueError(f'y has wrong dimension, {info_str_found_shape(y)}')
#    419                                                       if 1 <= Q != y.shape[-1]:
#    420                                                           raise ValueError(f'y has wrong dimension, {info_str_found_shape(y)}')
#    421
#    422                                                   # -------- check sample weight --------
#    423        50          0.5      0.0      0.0          if sample_weights is None:
#    424        50         47.2      0.9      0.0              sample_weights = np.broadcast_to(1., y.shape[:-1])
#    425                                                   else:
#    426                                                       if np.shape(sample_weights) != y.shape[:-1]:
#    427                                                           raise ValueError(f'sample_weights has wrong shape, {info_str_found_shape(sample_weights)}')
#    428
#    429                                                   # -------- calc xi2 --------
#    430        50          1.0      0.0      0.0          if self._steady_state:
#    431                                                       self._xi2 = self._cost_terms.get_steady_state_W(dim_order).flatten()
#    432        50          0.5      0.0      0.0          elif self._calc_W and not self._steady_state:
#    433                                                       q = 2
#    434                                                       xi_prev = self._nd_xi_q_recursion(q, y, sample_weights, dim_order[0])
#    435                                                       for nd_dim in dim_order[1:]:
#    436                                                           xi_prev = self._nd_xi_q_asterisk_l_recursion(xi_prev, q, y, sample_weights, nd_dim)
#    437                                                       self._xi2 = xi_prev
#    438
#    439                                                   # -------- calc xi1 --------
#    440        50          0.6      0.0      0.0          if self._calc_xi:
#    441        50          0.6      0.0      0.0              q = 1
#    442        50     132268.8   2645.4     99.0              xi_prev = self._nd_xi_q_recursion(q, y, sample_weights, dim_order[0])
#    443        50         34.2      0.7      0.0              for nd_dim in dim_order[1:]:
#    444                                                           xi_prev = self._nd_xi_q_asterisk_l_recursion(xi_prev, q, y, sample_weights, nd_dim)
#    445        50          5.5      0.1      0.0              self._xi1 = xi_prev
#    446
#    447                                                   # -------- calc xi0 --------
#    448        50          1.3      0.0      0.0          if self._calc_kappa:
#    449                                                       q = 0
#    450                                                       xi_prev = self._nd_xi_q_recursion(q, y, sample_weights, dim_order[0])
#    451                                                       for nd_dim in dim_order[1:]:
#    452                                                           xi_prev = self._nd_xi_q_asterisk_l_recursion(xi_prev, q, y, sample_weights, nd_dim)
#    453                                                       self._xi0 = xi_prev[..., 0]
#    454
#    455                                                   # -------- calc nu --------
#    456                                                   # TODO

# %% [markdown]
# ### Hotspot bar chart
#
# Visual breakdown of which lines dominate the runtime (lines with zero time are excluded).

# %%
# Extract per-line stats for lfilter_forward_cascade_xi
stats = lp.get_stats()
unit  = stats.unit  # seconds per timer tick

func_key = None
for key in stats.timings:
    if key[2] == 'lfilter_forward_cascade_xi':
        func_key = key
        break

if func_key is None:
    available = [k[2] for k in stats.timings]
    raise RuntimeError(f"No profiling data found. Keys in stats: {available}")

filename, start_line, _ = func_key
timings = stats.timings[func_key]   # [(lineno, nhits, total_time), ...]

# Use the unwrapped function for source inspection
src_lines = inspect.getsource(lfilter_forward_unwrapped).splitlines()
src_start = inspect.getsourcelines(lfilter_forward_unwrapped)[1]

# Divide by N_repeat to get per-call average ms
timing_map = {lineno: total_time * unit * 1e3 / N_repeat for lineno, nhits, total_time in timings}

REST_THRESHOLD_MS = 0.1

labels, values = [], []
rest_ms = 0.0
for lineno, ms in sorted(timing_map.items()):
    if ms <= 0:
        continue
    if ms < REST_THRESHOLD_MS:
        rest_ms += ms
        continue
    rel = lineno - src_start
    src = src_lines[rel].strip() if rel < len(src_lines) else ''
    labels.append(f"L{lineno}: {src[:55]}")
    values.append(ms)

# Append the "rest" bar
if rest_ms > 0:
    labels.append(f'rest  (<{REST_THRESHOLD_MS} ms each)')
    values.append(rest_ms)

# Sort by descending time (keep "rest" at end by sorting only the main entries)
n_main = len(values) - (1 if rest_ms > 0 else 0)
order  = np.argsort(values[:n_main])[::-1].tolist()
if rest_ms > 0:
    order.append(n_main)   # rest always last
labels   = [labels[i] for i in order]
values   = [values[i] for i in order]
total_ms = sum(values)

# Colour bars by fraction of total time; rest gets a distinct grey
palette = []
for i, v in enumerate(values):
    if labels[i].startswith('rest'):
        palette.append(lm.NORD['fg3'] if 'fg3' in lm.NORD else '#6c7a89')
    elif v / total_ms > 0.3:
        palette.append(lm.NORD['red'])
    elif v / total_ms > 0.1:
        palette.append(lm.NORD['yellow'])
    else:
        palette.append(lm.NORD['blue'])

fig, ax = plt.subplots(figsize=(10, max(3, 0.4 * len(labels))), dpi=200)
fig.patch.set_facecolor(lm.NORD['bg'])
ax.set_facecolor(lm.NORD['bg2'])
for spine in ax.spines.values():
    spine.set_edgecolor(lm.NORD['border'])
ax.tick_params(colors=lm.NORD['fg'], which='both')
ax.xaxis.label.set_color(lm.NORD['fg'])

bars = ax.barh(range(len(labels)), values, color=palette,
               edgecolor=lm.NORD['bg'], linewidth=0.6)
ax.bar_label(bars, fmt='%.1f ms', padding=4, color=lm.NORD['fg'], fontsize=8)

ax.set_yticks(range(len(labels)))
ax.set_yticklabels(labels, fontsize=7.5, color=lm.NORD['fg'], fontfamily='monospace')
ax.invert_yaxis()
ax.set_xlabel('Time (ms, per-call average)', color=lm.NORD['fg'])
ax.set_title(
    f'lfilter_forward_cascade_xi — line-by-line (K={K_lp:,}, avg over {N_repeat} calls, total={total_ms:.1f} ms)',
    color=lm.NORD['white'], pad=10
)
ax.grid(True, axis='x', color=lm.NORD['border'], linestyle='--', linewidth=0.6, alpha=0.6)
ax.set_axisbelow(True)

from matplotlib.patches import Patch
legend_handles = [
    Patch(color=lm.NORD['red'],    label='>30 % of total'),
    Patch(color=lm.NORD['yellow'], label='10-30 %'),
    Patch(color=lm.NORD['blue'],   label='<10 %'),
    Patch(color=palette[-1],       label=f'rest  (<{REST_THRESHOLD_MS} ms each)'),
]
ax.legend(handles=legend_handles, facecolor=lm.NORD['bg3'], edgecolor=lm.NORD['border'],
          labelcolor=lm.NORD['fg'], framealpha=0.9, fontsize=8)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Scaling visualization
#
# Wall time and peak memory as a function of signal length `K` (log–log scale).

# %%
colors = [lm.NORD['blue'], lm.NORD['green'], lm.NORD['indigo']]
Ks_arr = np.array(Ks)

fig, axes = plt.subplots(1, 2, figsize=(12, 4), dpi=200)
fig.patch.set_facecolor(lm.NORD['bg'])

for ax in axes:
    ax.set_facecolor(lm.NORD['bg2'])
    for spine in ax.spines.values():
        spine.set_edgecolor(lm.NORD['border'])
    ax.tick_params(colors=lm.NORD['fg'], which='both')
    ax.xaxis.label.set_color(lm.NORD['fg'])
    ax.yaxis.label.set_color(lm.NORD['fg'])
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.grid(True, color=lm.NORD['border'], linestyle='--', linewidth=0.6, alpha=0.7, which='both')
    ax.set_axisbelow(True)

ax_t, ax_m = axes

for func, color in zip(func_names, colors):
    t_med = np.array([np.median([r.elapsed_s * 1e3 for r in records_per_K[K][func]]) for K in Ks])
    t_min = np.array([min(r.elapsed_s * 1e3     for r in records_per_K[K][func]) for K in Ks])
    t_max = np.array([max(r.elapsed_s * 1e3     for r in records_per_K[K][func]) for K in Ks])
    m_med = np.array([np.median([r.peak_bytes / 1024 for r in records_per_K[K][func]]) for K in Ks])
    m_min = np.array([min(r.peak_bytes / 1024        for r in records_per_K[K][func]) for K in Ks])
    m_max = np.array([max(r.peak_bytes / 1024        for r in records_per_K[K][func]) for K in Ks])

    ax_t.plot(Ks_arr, t_med, color=color, marker='o', linewidth=1.5, markersize=5, label=func)
    ax_t.fill_between(Ks_arr, t_min, t_max, color=color, alpha=0.15)

    ax_m.plot(Ks_arr, m_med, color=color, marker='o', linewidth=1.5, markersize=5, label=func)
    ax_m.fill_between(Ks_arr, m_min, m_max, color=color, alpha=0.15)

ax_t.set_xlabel('Signal length K', color=lm.NORD['fg'])
ax_t.set_ylabel('Wall time (ms)', color=lm.NORD['fg'])
ax_t.set_title(f'Computation time vs. K  (median ± min/max, N={N_repeat})', color=lm.NORD['white'], pad=10)
ax_t.legend(facecolor=lm.NORD['bg3'], edgecolor=lm.NORD['border'],
            labelcolor=lm.NORD['fg'], framealpha=0.9, fontsize=8)

ax_m.set_xlabel('Signal length K', color=lm.NORD['fg'])
ax_m.set_ylabel('Peak memory (KB)', color=lm.NORD['fg'])
ax_m.set_title(f'Peak memory vs. K  (median ± min/max, N={N_repeat})', color=lm.NORD['white'], pad=10)
ax_m.legend(facecolor=lm.NORD['bg3'], edgecolor=lm.NORD['border'],
            labelcolor=lm.NORD['fg'], framealpha=0.9, fontsize=8)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Raw records
#
# `lm.profiling.get_records()` returns `{func_name: [_Record, ...]}`.
# Each `_Record` has `.elapsed_s`, `.peak_bytes`, and `._pstats` (a `pstats.Stats` object).

# %%
# Print per-K summary from records_per_K — first record per K, with CPU flag
print(f"{'K':>10}  {'function':<40}  {'time (ms)':>10}  {'peak (KB)':>10}  {'cpu %':>7}  {'ok?':>4}")
print("─" * 90)
for K in Ks:
    for name, recs in records_per_K[K].items():
        r = recs[0]
        cpu_str = f"{r.cpu_percent:5.1f}%" if not math.isnan(r.cpu_percent) else "  n/a "
        ok = "✓" if r.is_reliable else "⚠"
        print(f"{K:>10,}  {name:<40}  {r.elapsed_s*1e3:>10.2f}  {r.peak_bytes/1024:>10.1f}  {cpu_str:>7}  {ok:>4}")
# Out:
#          K  function                                   time (ms)   peak (KB)    cpu %   ok?
# ──────────────────────────────────────────────────────────────────────────────────────────
#      1,000  lfilter_forward_cascade_xi                      0.98        88.2     0.0%     ✓
#     10,000  lfilter_forward_cascade_xi                      1.52       651.0    20.0%     ✓
#    100,000  lfilter_forward_cascade_xi                      8.13      6275.9     0.0%     ✓
#  1,000,000  lfilter_forward_cascade_xi                     59.52     62525.8     5.6%     ✓

# %% [markdown]
# ## Summary
#
# This notebook profiles the **pre-optimization** code (C-order scratch buffer `xi0`, C-order `xi_curr`).
#
# | Section | Key finding |
# |---------|-------------|
# | Profiling sweep | Time and peak memory scale linearly with K (O(K) per call) |
# | cProfile breakdown | `lfilter_forward_cascade_xi` and the cascade inner loop dominate runtime |
# | Line profiler | Column writes `xi0[:, n_]` (C-order, strided) and `einsum` coupling are the hotspot lines |
# | Scaling plot | Both time and memory are proportional to K with no cache cliff |
#
# The line profiler will show `xi0[:, n_]` as a significant cost — writing strided columns into
# a C-order array. This is the operation that F-order eliminates.
#
# > To see how much faster the optimized code is, see **[code913.3](coding-code913.3-applied.ipynb)** (before/after pipeline benchmark).
# > To understand *why* F-order is faster, see **[code913.1](coding-code913.1-cascade-variants.ipynb)**.

# %%
# Restore the production (optimised) implementations.
# Run this cell manually if any earlier cell raised an exception while the
# before-implementations were active, to leave the module in a clean state.
_rlf_mod.lfilter_forward_cascade_xi  = _orig_fw
_rlf_mod.lfilter_backward_cascade_xi = _orig_bw
lm.RLSAlssm._nd_xi_q_recursion       = _orig_nd

print("✓ Module restored to production implementations.")
# Out:
# ✓ Module restored to production implementations.
